# %%
import numpy as np
import sys
import os
import calendar
from IPython.display import display, HTML
import glob
import lxml
import html5lib
import requests
import time
from ftplib import FTP
import xml.etree.ElementTree as ET
import xmltodict
from datetime import timedelta
from datetime import datetime
import datetime as dt
import pytz
from dateutil import tz
from IPython.display import display, HTML
from pathlib import Path
from requests_auth import OktaAuthorizationCodePKCE, JsonTokenFileCache
import xlsxwriter
from openpyxl import Workbook
import numpy as np
import scipy.stats as si
import sympy as sy
from sympy.stats import Normal, cdf
from sympy import init_printing
import matplotlib as plt
import plotly.graph_objects as go
from datetime import date
from dateutil.relativedelta import *
from datetime import date, timedelta
from calendar import monthrange
from datetime import datetime
from calendar import month_abbr
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

init_printing()

starting_time = time.time()
print('Module setup is done')
# Out:
# Module setup is done

# %% [markdown]
# ### CALLING THE PYMERCURE FOR THE FOLLOWING NEXT 12 MONTHS OF CURVES

# %%
def get_forward_month_list():
    now = datetime.now()
    return [(now.replace(day=1) + relativedelta(months=i+1)).strftime('%Y-%m-%d') for i in range(12)]
date_list=[get_forward_month_list()]

cl = Client()
start_date = pd.Timestamp(dt.datetime.today() +timedelta(days=-1000), tz='Europe/Brussels')
end_date = pd.Timestamp(dt.datetime.today()+timedelta(days=0), tz='Europe/Brussels')
first_curve=[]

"""
This part included a portion to retrieve underlying curves. Please insert yours
first output---> first_curve (including a data frame which includes monhtly forward prices of the first given underlying)
first output---> second_curve (including a data frame which includes monhtly forward prices of the second given underlying)
"""

# %% [markdown]
# ### FIRST CURVE DATAVIZ

# %%
df1=first_curve
trading_days = 252
returns = np.log(df1/df1.shift(1))
returns.fillna(0, inplace=True)
volatility = returns.rolling(window=trading_days).std()*np.sqrt(trading_days)
vol1=volatility
vol1=pd.DataFrame(vol1)
vola1=vol1.iloc[-1]
last_val1=df1.iloc[-1]

data1 =  [
        go.Scatter(x=vol1.index, y=vol1.iloc[:,0], line={"color": 'blue'}, name=df1.columns[0],connectgaps=True),
        go.Scatter(x=vol1.index, y=vol1.iloc[:,1], line={"color": 'red'}, name=df1.columns[1], connectgaps=True),
        go.Scatter(x=vol1.index, y=vol1.iloc[:,2], line={"color": 'green'}, name=df1.columns[2],connectgaps=True),
        go.Scatter(x=vol1.index, y=vol1.iloc[:,3], line={"color": 'black'}, name=df1.columns[3], connectgaps=True),
        go.Scatter(x=vol1.index, y=vol1.iloc[:,4], line={"color": 'yellow'}, name=df1.columns[4],connectgaps=True),
        go.Scatter(x=vol1.index, y=vol1.iloc[:,5], line={"color": 'pink'}, name=df1.columns[5], connectgaps=True),
        go.Scatter(x=vol1.index, y=vol1.iloc[:,6], line={"color": 'orange'}, name=df1.columns[6],connectgaps=True),
        go.Scatter(x=vol1.index, y=vol1.iloc[:,7], line={"color": 'purple'}, name=df1.columns[7], connectgaps=True),
        go.Scatter(x=vol1.index, y=vol1.iloc[:,8], line={"color": 'grey'}, name=df1.columns[8], connectgaps=True),
        go.Scatter(x=vol1.index, y=vol1.iloc[:,9], line={"color": 'brown'}, name=df1.columns[9],connectgaps=True),
        go.Scatter(x=vol1.index, y=vol1.iloc[:,10], line={"color": 'cyan'}, name=df1.columns[10], connectgaps=True),
        go.Scatter(x=vol1.index, y=vol1.iloc[:,11], line={"color": 'gold'}, name=df1.columns[11],connectgaps=True),
        
        ]

layout = dict(
    yaxis=dict(title='Volatility (%)'),
    legend=dict(x=0, y=-0.1, orientation='h'),
    title='252 Working Day Volatility of Spanish Power Curve'
  
)

fig_vol1= go.Figure(data=data1, layout=layout)

# %% [markdown]
# ### SECOND CURVE AND DATAVIZ

# %%
df2=second_curve
trading_days = 252
returns = np.log(df2/df2.shift(1))
returns.fillna(0, inplace=True)
volatility = returns.rolling(window=trading_days).std()*np.sqrt(trading_days)
vol2=volatility
vol2=pd.DataFrame(vol2)
vola2=vol2.iloc[-1]
last_val2=df2.iloc[-1]

data2 =  [
        go.Scatter(x=vol2.index, y=vol2.iloc[:,0], line={"color": 'blue'}, name=df2.columns[0],connectgaps=True),
        go.Scatter(x=vol2.index, y=vol2.iloc[:,1], line={"color": 'red'}, name=df2.columns[1], connectgaps=True),
        go.Scatter(x=vol2.index, y=vol2.iloc[:,2], line={"color": 'green'}, name=df2.columns[2],connectgaps=True),
        go.Scatter(x=vol2.index, y=vol2.iloc[:,3], line={"color": 'black'}, name=df2.columns[3], connectgaps=True),
        go.Scatter(x=vol2.index, y=vol2.iloc[:,4], line={"color": 'yellow'}, name=df2.columns[4],connectgaps=True),
        go.Scatter(x=vol2.index, y=vol2.iloc[:,5], line={"color": 'pink'}, name=df2.columns[5], connectgaps=True),
        go.Scatter(x=vol2.index, y=vol2.iloc[:,6], line={"color": 'orange'}, name=df2.columns[6],connectgaps=True),
        go.Scatter(x=vol2.index, y=vol2.iloc[:,7], line={"color": 'purple'}, name=df2.columns[7], connectgaps=True),
        go.Scatter(x=vol2.index, y=vol2.iloc[:,8], line={"color": 'grey'}, name=df2.columns[8], connectgaps=True),
        go.Scatter(x=vol2.index, y=vol2.iloc[:,9], line={"color": 'brown'}, name=df2.columns[9],connectgaps=True),
        go.Scatter(x=vol2.index, y=vol2.iloc[:,10], line={"color": 'cyan'}, name=df2.columns[10], connectgaps=True),
        go.Scatter(x=vol2.index, y=vol2.iloc[:,11], line={"color": 'gold'}, name=df2.columns[11],connectgaps=True),
        
        ]

layout = dict(
    yaxis=dict(title='Volatility (%)'),
    legend=dict(x=0, y=-0.1, orientation='h'),
    title='252 Working Day Volatility of French Power Curve'
  
)

fig_vol2= go.Figure(data=data2, layout=layout)

# %% [markdown]
# ## CALCULATION OF OPTION GREEKS

# %% [markdown]
# ### Correlation of given series

# %%
correlations=[]
for i in range(0,12):
    r=pd.DataFrame(np.corrcoef(df1.iloc[:,i],df2.iloc[:,i]))
    corr=r.iloc[0,1]
    correlations.append(corr)
#correls=pd.concat(correls,axis=1)
correlations=pd.DataFrame(correlations)
correlations.columns=['Correlations']
correlations.index=second_curve.columns.T

vola_K=np.sqrt(pd.DataFrame(vola1 ** 2 + vola2 ** 2 - 2 * vola1 * vola2 * correlations['Correlations']))

# %% [markdown]
# ### Number of days to the each Mid-Month

# %%
T_value=pd.DataFrame(date_list).T
T_value.columns=['MidMonth']
T_value['MidMonth']=pd.to_datetime(T_value['MidMonth'],format='%Y-%m-%d')
T_value['MidMonth2']=''
T_value['MidMonth2']=T_value['MidMonth']+timedelta(days=14)
T_value['Today']=date.today()
T_value['MidMonth2']=pd.to_datetime(T_value['MidMonth2']).dt.date
T_value['Today']=pd.to_datetime(T_value['Today']).dt.date

T_value['NumberofDays']=(T_value['MidMonth2']-T_value['Today'])
T=T_value['NumberofDays'].dt.days
T.index=second_curve.columns.T

# %% [markdown]
# ### Appending calculated greeks

# %%
greeks_frame=[correlations,vola1,vola2,last_val1,last_val2,vola_K,T]
greeks=pd.concat(greeks_frame,axis=1)
greeks.columns=['Correlation','Volatility1','Volatility2','LastClosing1','LastClosing2','MutualVola_K','T_Value_days']
greeks.loc['--MEAN']=greeks.mean()

# %% [markdown]
# ## DEFINION OF EUROPEAN VANILLA OPTION

# %%
def european_vanilla_option(S, K, T, r, sigma, option = 'call'):
    #S: First price set as spot price.
    #K: Second price set as the strike price.
    #T: Time to maturity.
    #r: interest rate
    #sigma: volatility of underlying asset
    #cdf: cumulative distribution function. A cumulative probability refers to the probability that the value of a random variables falls within aspecified range. Gives the area under the probability density function -from minus infinity to X-. F(x)= P|X<=x| where F(x) lies only within 0 and 1.
    
    d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
    d2 = (np.log(S / K) + (r - 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
    
    if option == 'call':
        result = (S * si.norm.cdf(d1, 0.0, 1.0) - K * np.exp(-r * T) * si.norm.cdf(d2, 0.0, 1.0))
    if option == 'put':
        result = (K * np.exp(-r * T) * si.norm.cdf(-d2, 0.0, 1.0) - S * si.norm.cdf(-d1, 0.0, 1.0))
        
    return result

# %% [markdown]
# ### Output Screen

# %%
display(fig_vol1)
display(fig_vol2)
put_values=european_vanilla_option(S=greeks['LastClosing1'],K=greeks['LastClosing2'],T=greeks['T_Value_days'],r=0.023,sigma=greeks['MutualVola_K'],option='put')
call_values=european_vanilla_option(S=greeks['LastClosing1'],K=greeks['LastClosing2'],T=greeks['T_Value_days'],r=0.023,sigma=greeks['MutualVola_K'],option='call')
greeks['PUT_STRIKE_VALUES']=put_values
greeks['CALL_STRIKE_VALUES']=call_values
display(greeks)
# Out:
#         Correlation  Volatility1  Volatility2  LastClosing1  LastClosing2  \
# APR21      0.677856     0.259609     0.271095     45.100000     49.250033
# MAY21      0.706182     0.218630     0.441002     48.976839     46.499968
# JUN21      0.647510     0.222807     0.441082     55.500000     49.137000
# JUL21      0.556955     0.178447     0.278419     59.709000     51.891000
# AUG21      0.643783     0.183350     0.292293     58.622000     48.713000
# SEP21      0.687100     0.166914     0.241521     61.729000     56.506000
# OCT21      0.787724     0.164586     0.208815     59.006000     60.296000
# NOV21      0.796106     0.161744     0.180549     61.220000     68.868000
# DEC21      0.784759     0.164429     0.182414     61.002000     68.268000
# JAN22      0.690532     0.175235     0.164306     55.466000     70.385000
# FEB22      0.468607     0.155164     0.164306     53.841000     70.385000
# MAR22      0.514113     0.185240     0.198280     50.206000     59.785000
# ...
